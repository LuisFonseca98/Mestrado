# %% [markdown]
# # **COMPUTACIONAL DRUG DISCOVERY**
#
#
# Com este projeto, irá ser feito um estudo/aplicaçao onde vai ser estudado diferentes tipos de moléculas e células que contribuem para diferentes tipos de doenças(corona, HIV, sarampo, etc).
# Pegando uma base de dados já existente, irá ser feito um estudo das diferentes particulares de organismos. Nomeadamente as suas diferentes características.
# Este tipo de dados, ao ser estudado e analisado, poderá ser usado mais tarde para contribuir para medicamentos novos ou melhorar os já existentes.
# Desta maneira poderá sempre surgir alguma estirpe/doença nova que a pessoa nao conheça. Com este projeto, podemos garantir também que irá previsto algum tipo de doença desconhecida que possa vir a surgir num futuro próximo.
# O processo deste projeto vai consistir no seguinte:
# <ul>
#     <li>Obter dados da base de dados</li>
#     <li>Construir um modelo de ML para agrupar os dados</li>
#     <li>Treinar o modelo</li>
#     <LI>Após ser treinado, imprimir resultados, tirar conclusoes, mostrar gráficos e retirar um estudo das melhores células</LI>
# </ul>

# %% [markdown]
# # **Ferramentas**
# Base de dados: chembl (contém uma vasta coleçao de dados, contento diferentes doenças com os seus diferentes organimos)<br>
# Python: vai ser usada esta linguagem para desenvolver o projeto. Contém uma vasta coleçao de bibliotecas que permite usar machine learning e agrupar os dados
# <ul>
#     <li>Pandas: biblioteca fácil de usar para análise de dados e manipulaçao de ferramentas.</li>
# </ul>
# (Opcional) StarUML: vai ser usada para desenhar a arquitetura do projeto. Útil para esboços e como irá o projeto ser desenvolvido

# %% [markdown]
# # **Base de dados ChEMBL**
# ChEMBL ou ChEMBLdb é uma base de dados que contém químicos com curadoria manual de moléculas bioativas com propriedades indutoras de drogas.
# Pode ser acedido neste link: https://www.ebi.ac.uk/chembl/

# %% [markdown]
# # **Importe de bibliotecas**

# %%
#instaling libary
#pip install chembl-webresource-client
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
#Exemplo: procurar pela target protei
target = new_client.target
target_query = target.search('aromatase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P11511', 'xref_name': None, 'xre...       Homo sapiens
# 1  [{'xref_id': 'P22443', 'xref_name': None, 'xre...  Rattus norvegicus
#
#               pref_name  score  species_group_flag target_chembl_id  \
# 0  Cytochrome P450 19A1   20.0               False       CHEMBL1978
# 1  Cytochrome P450 19A1   20.0               False       CHEMBL3859
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P11511', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'P22443', 'component_descriptio...  SINGLE PROTEIN   10116

# %%
#selecionar dados de 'bioactivity' para o SARS coronavirus
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL3859'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
df = pd.DataFrame.from_dict(res)
df
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None       530035                  []
# 1         None             None       539290                  []
# 2         None             None       553204                  []
# 3         None             None       615833                  []
# 4         None             None       789248                  []
# 5         None             None       819891                  []
# 6         None             None     15742388                  []
# 7         None             None     15742389                  []
# 8         None             None     15742390                  []
# 9         None             None     16433981                  []
# 10        None             None     16433982                  []
#
#    assay_chembl_id                                  assay_description  \
# 0     CHEMBL661155      Inhibition of rat ovarian Cytochrome P450 19A
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
#save the results in a csv file
#df.to_csv('bioactivity_data.csv', index=False)
